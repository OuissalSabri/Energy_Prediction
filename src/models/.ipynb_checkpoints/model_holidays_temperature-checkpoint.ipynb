# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from prophet import Prophet

# %% [markdown]
# ## Read Data

# %%
filename = "../../../data/data.csv"

# %%
df = pd.read_csv(filename)

# %%
df.count()
# Out:
# datetime       9041
# consumption    9041
# temp           9041
# dtype: int64

# %%
df.head()
# Out:
#                  datetime  consumption  temp
# 0  12/19/2018, 3:00:02 PM          249    69
# 1  12/19/2018, 4:00:03 PM          294    69
# 2  12/19/2018, 6:00:02 PM          287    69
# 3  12/19/2018, 7:00:02 PM          285    69
# 4  12/19/2018, 8:00:02 PM          228    69

# %% [markdown]
# ### Convert index to datetime

# %%
df = pd.read_csv(filename,index_col = 'datetime',parse_dates=['datetime'])
df.head(5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2548\1436439848.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(filename,index_col = 'datetime',parse_dates=['datetime'])
#                      consumption  temp
# datetime
# 2018-12-19 15:00:02          249    69
# 2018-12-19 16:00:03          294    69
# 2018-12-19 18:00:02          287    69
# 2018-12-19 19:00:02          285    69
# 2018-12-19 20:00:02          228    69

# %% [markdown]
# ### Verify that no value is null

# %%
df.isna().sum()
# Out:
# consumption    0
# temp           0
# dtype: int64

# %%
df['consumption'] = df['consumption'] + 1

# %%
min(df.consumption)
# Out:
# 1

# %% [markdown]
# # Energy Consumption vs Datetime Graph

# %%
df.plot(y=['consumption'],figsize=(12,5),legend=True)
plt.show()

# %% [markdown]
# # Temperature vs Datetime Graph

# %%
df.plot(y=['temp'],figsize=(12,5),legend=True)
plt.show()

# %% [markdown]
# ## Maximum Energy Consumption Values

# %%
df.nlargest(10,'consumption')
# Out:
#                      consumption  temp
# datetime
# 2019-05-16 12:00:02         1643    96
# 2019-05-16 11:00:01         1620    96
# 2019-05-21 15:00:02         1594    98
# 2019-05-21 16:00:02         1583    98
# 2019-05-22 14:00:02         1568    99
# 2019-05-22 15:00:02         1568    99
# 2019-05-22 12:00:01         1554    99
# 2019-05-22 13:00:02         1551    99
# 2019-05-10 15:00:02         1549    96
# 2019-05-22 16:00:01         1548    99

# %% [markdown]
# # Maximum Temperature Values (in °F)

# %%
df.nlargest(10,'temp')
# Out:
#                      consumption  temp
# datetime
# 2019-05-27 22:00:02          490   100
# 2019-05-27 23:00:02          484   100
# 2019-05-28 00:00:02          470   100
# 2019-05-28 01:00:02          464   100
# 2019-05-28 02:00:01          422   100
# 2019-05-28 03:00:02          389   100
# 2019-05-28 04:00:02          369   100
# 2019-05-28 05:00:02          304   100
# 2019-05-28 06:00:02          246   100
# 2019-05-28 07:00:01          402   100

# %%
df = df.reset_index()

# %%
df.count()
# Out:
# datetime       9041
# consumption    9041
# temp           9041
# dtype: int64

# %% [markdown]
# ## Changing dataframe format specific to Prophet Model

# %%
df = df.rename(columns={'datetime':'ds','consumption':'y'})

# %%
df.count()
# Out:
# ds      9041
# y       9041
# temp    9041
# dtype: int64

# %%
df.nlargest(10,'y')
# Out:
#                       ds     y  temp
# 3502 2019-05-16 12:00:02  1643    96
# 3501 2019-05-16 11:00:01  1620    96
# 3625 2019-05-21 15:00:02  1594    98
# 3626 2019-05-21 16:00:02  1583    98
# 3648 2019-05-22 14:00:02  1568    99
# 3649 2019-05-22 15:00:02  1568    99
# 3646 2019-05-22 12:00:01  1554    99
# 3647 2019-05-22 13:00:02  1551    99
# 3361 2019-05-10 15:00:02  1549    96
# 3650 2019-05-22 16:00:01  1548    99

# %% [markdown]
# ## Taking log of consumption values

# %%
df.y = np.log(df.y)

# %% [markdown]
# ## Model Fitting

# %%
model = Prophet()
model.add_country_holidays(country_name='IN')
model.add_regressor('temp')
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\holidays\countries\india.py:101: Warning: Diwali and Holi holidays available from 2001 to 2030 only
#   warnings.warn(warning_msg, Warning)

# %%
model.fit(df)
# Out:
# 22:58:27 - cmdstanpy - INFO - Chain [1] start processing
# 22:58:30 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# # List of Holidays

# %%
model.train_holiday_names
# Out:
# 0        Makar Sankranti / Pongal
# 1                    Republic Day
# 2                Independence Day
# 3                  Gandhi Jayanti
# 4                      Labour Day
# 5                          Diwali
# 6                            Holi
# 7     Day of Ashura* (*estimated)
# 8            Mawlid* (*estimated)
# 9       Eid ul-Fitr* (*estimated)
# 10      Eid al-Adha* (*estimated)
# 11                    Palm Sunday
# 12                    Good Friday
# 13                  Easter Sunday
# 14             Feast of Pentecost
# 15                  Christmas Day
# dtype: object

# %% [markdown]
# ## Predictions

# %%
prediction=model.predict(df)

# %%
org_prediction = prediction.copy()

# %%
prediction.nlargest(10,'yhat')
# Out:
#                       ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 3956 2019-06-04 10:00:02  5.636071    5.787469    8.988096     5.636071
# 3957 2019-06-04 11:00:03  5.636055    6.036271    9.083604     5.636055
# 3788 2019-05-28 10:00:02  5.638733    5.821601    8.986391     5.638733
# 3789 2019-05-28 11:00:01  5.638717    5.782710    8.966751     5.638717
# 3958 2019-06-04 12:00:02  5.636039    5.771716    8.976815     5.636039
# 3620 2019-05-21 10:00:02  5.616727    5.917860    8.988339     5.616727
# 3621 2019-05-21 11:00:02  5.616887    5.725634    8.937993     5.616887
# 3961 2019-06-04 15:00:02  5.635992    5.710409    8.914837     5.635992
# 3955 2019-06-04 09:00:02  5.636087    5.720503    8.847237     5.636087
# 3962 2019-06-04 16:00:02  5.635976    5.547527    8.892699     5.635976
#
#       trend_upper  Christmas Day  Christmas Day_lower  Christmas Day_upper  \
# 3956     5.636071            0.0                  0.0                  0.0
# 3957     5.636055            0.0                  0.0                  0.0
# 3788     5.638733            0.0                  0.0                  0.0
# 3789     5.638717            0.0                  0.0                  0.0
# 3958     5.636039            0.0                  0.0                  0.0
# 3620     5.616727            0.0                  0.0                  0.0
# 3621     5.616887            0.0                  0.0                  0.0
# 3961     5.635992            0.0                  0.0                  0.0
# 3955     5.636087            0.0                  0.0                  0.0
# 3962     5.635976            0.0                  0.0                  0.0
#
#       Day of Ashura* (*estimated)  ...      temp  temp_lower  temp_upper  \
# 3956                          0.0  ...  0.182553    0.182553    0.182553
# 3957                          0.0  ...  0.182553    0.182553    0.182553
# 3788                          0.0  ...  0.255910    0.255910    0.255910
# 3789                          0.0  ...  0.255910    0.255910    0.255910
# 3958                          0.0  ...  0.182553    0.182553    0.182553
# 3620                          0.0  ...  0.226567    0.226567    0.226567
# 3621                          0.0  ...  0.226567    0.226567    0.226567
# 3961                          0.0  ...  0.182553    0.182553    0.182553
# 3955                          0.0  ...  0.182553    0.182553    0.182553
# 3962                          0.0  ...  0.182553    0.182553    0.182553
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 3956  0.826529      0.826529      0.826529                   0.0
# 3957  0.796662      0.796662      0.796662                   0.0
# 3788  0.826529      0.826529      0.826529                   0.0
# 3789  0.796680      0.796680      0.796680                   0.0
# 3958  0.763242      0.763242      0.763242                   0.0
# 3620  0.826529      0.826529      0.826529                   0.0
# 3621  0.796671      0.796671      0.796671                   0.0
# 3961  0.648143      0.648143      0.648143                   0.0
# 3955  0.852170      0.852170      0.852170                   0.0
# 3962  0.607050      0.607050      0.607050                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 3956                         0.0                         0.0  7.511631
# 3957                         0.0                         0.0  7.509410
# 3788                         0.0                         0.0  7.390180
# 3789                         0.0                         0.0  7.388010
# 3958                         0.0                         0.0  7.378544
# 3620                         0.0                         0.0  7.338831
# 3621                         0.0                         0.0  7.336811
# 3961                         0.0                         0.0  7.300389
# 3955                         0.0                         0.0  7.285211
# 3962                         0.0                         0.0  7.272680
#
# [10 rows x 76 columns]

# %% [markdown]
# ### Let's check for effect of Gandhi Jayanti on Energy consumption value

# %%
prediction.nlargest(10,'Gandhi Jayanti')[['ds','Gandhi Jayanti']]
# Out:
#                       ds  Gandhi Jayanti
# 6752 2019-10-02 00:00:01        0.061107
# 6753 2019-10-02 01:00:02        0.061107
# 6754 2019-10-02 02:00:01        0.061107
# 6755 2019-10-02 03:00:02        0.061107
# 6756 2019-10-02 04:00:02        0.061107
# 6757 2019-10-02 05:00:02        0.061107
# 6758 2019-10-02 06:00:02        0.061107
# 6759 2019-10-02 07:00:02        0.061107
# 6760 2019-10-02 08:00:01        0.061107
# 6761 2019-10-02 09:00:02        0.061107

# %% [markdown]
# # Actual vs Predicted Energy Values Plot
# Black points represents the actual values, blue  points represents the predicted values and the light blue margin represents the lower and upper bound of predicted values for certain points.

# %%
fig = model.plot(prediction)

# %% [markdown]
# ## Monthly, Daywise and Timewise distribution

# %% [markdown]
# The values in the graph basically represents the effect of values corresponding to x-axis on result predicted on y-axis

# %%
fig = model.plot_components(prediction)

# %%
df.head()
# Out:
#                    ds         y  temp
# 0 2018-12-19 15:00:02  5.521461    69
# 1 2018-12-19 16:00:03  5.686975    69
# 2 2018-12-19 18:00:02  5.662960    69
# 3 2018-12-19 19:00:02  5.655992    69
# 4 2018-12-19 20:00:02  5.433722    69

# %%
prediction.head()
# Out:
#                    ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 0 2018-12-19 15:00:02  3.923898    3.066517    6.303241     3.923898
# 1 2018-12-19 16:00:03  3.924663    3.203070    6.329763     3.924663
# 2 2018-12-19 18:00:02  3.926194    2.842766    6.098560     3.926194
# 3 2018-12-19 19:00:02  3.926960    2.741285    5.827894     3.926960
# 4 2018-12-19 20:00:02  3.927725    2.482773    5.616143     3.927725
#
#    trend_upper  Christmas Day  Christmas Day_lower  Christmas Day_upper  \
# 0     3.923898            0.0                  0.0                  0.0
# 1     3.924663            0.0                  0.0                  0.0
# 2     3.926194            0.0                  0.0                  0.0
# 3     3.926960            0.0                  0.0                  0.0
# 4     3.927725            0.0                  0.0                  0.0
#
#    Day of Ashura* (*estimated)  ...      temp  temp_lower  temp_upper  \
# 0                          0.0  ... -0.198904   -0.198904   -0.198904
# 1                          0.0  ... -0.198904   -0.198904   -0.198904
# 2                          0.0  ... -0.198904   -0.198904   -0.198904
# 3                          0.0  ... -0.198904   -0.198904   -0.198904
# 4                          0.0  ... -0.198904   -0.198904   -0.198904
#
#      weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  0.331774      0.331774      0.331774                   0.0
# 1  0.355118      0.355118      0.355118                   0.0
# 2  0.404049      0.404049      0.404049                   0.0
# 3  0.428819      0.428819      0.428819                   0.0
# 4  0.453249      0.453249      0.453249                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  4.692999
# 1                         0.0                         0.0  4.730496
# 2                         0.0                         0.0  4.446625
# 3                         0.0                         0.0  4.247223
# 4                         0.0                         0.0  4.100802
#
# [5 rows x 76 columns]

# %% [markdown]
# ## Errors

# %%
true_val = np.exp(df.y)

# %%
pred_val = np.exp(org_prediction['yhat'])

# %%
mean_squared_error(y_true=true_val,y_pred=pred_val)
# Out:
# 40638.268725857386

# %%
mean_absolute_error(y_true=true_val,y_pred=pred_val)
# Out:
# 137.42839015784088

# %% [markdown]
# ## Prediction

# %%
data = ['2019-05-16 12:00:00']
test = pd.DataFrame(data, columns = ['ds'])

# %%
test['temp'] = 80

# %%
test
# Out:
#                     ds  temp
# 0  2019-05-16 12:00:00    80

# %%
val = model.predict(test)

# %%
val
# Out:
#                    ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 0 2019-05-16 12:00:00  5.597805    5.173816    8.332223     5.597805
#
#    trend_upper  Christmas Day  Christmas Day_lower  Christmas Day_upper  \
# 0     5.597805            0.0                  0.0                  0.0
#
#    Day of Ashura* (*estimated)  ...      temp  temp_lower  temp_upper  \
# 0                          0.0  ... -0.037518   -0.037518   -0.037518
#
#      weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  0.586111      0.586111      0.586111                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  6.745697
#
# [1 rows x 76 columns]

# %%
np.exp(val['yhat'])
# Out:
# 0    850.391296
# Name: yhat, dtype: float64

# %% [markdown]
# ## Saving Model

# %%
type(model)
# Out:
# prophet.forecaster.Prophet

# %%
pkl_path = "model.pkl"

# %%
model.stan_backend.logger = None

# %%
with open(pkl_path, 'wb') as fout:
    pickle.dump(model, fout)

# %%
with open('model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)
